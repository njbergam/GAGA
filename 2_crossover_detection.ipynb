# %%
from Functions import *
import pandas as pd

gr = pd.read_pickle("greenland_clean.pkl") 
period = [2003,2004]
gr = Graph(gr, period)
r= 5
gr.bbox_specialize([69.10-r, 69.10+r/4, -49.5-r, -49.5+r],add_label='helheim')
gr.visualize(tp='normal',saveto='temp')
gr.info()
crx = gr.crossovers()
# Out:
# number of total points: 3681963
# number of points in [2003, 2004]: 196199
# bbox [64.1, 70.35, -54.5, -44.5]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done

# %%
# Out:
# [ 7.  7.  7.  8.  8.  7.  8.  7. 12. 10.  9. 12. 11.  1.  3.  6.  9. 11.
#   9.  8.  5.  5. 13. 17. 12.  9.  9. 10.  8.  9.  8.  9. 10. 10.  0.  2.
#   2.  8. 11.  6.  6. 12.  7.  9.  3.  4.  4.  6. 13. 13. 10.  7.  7.  7.
#  12. 12.  8.  8.  8. 11. 11. 11. 11.  9. 10. 11. 12. 10.  9. 10.  4.  3.
#   5.  5.  5.  3.  2.  3.  5.  6.  7.  7.  8.  8.  8.  7.  3.  4.  0.  2.
#   2.  2.  1.  3.  6. 10.  9.  7.  2.  4.  4.  9.  0.  1.  1.  7.  4.  5.
#  13. 12.  9.  9. 10.  3.  7.  7.  7. 11.  8.  7. 10. 11. 11. 12. 12.  4.
#   3.  1.  6.  6.  6. 11. 11. 10.  8.  8.  4.  7. 11. 16. 11.  9. 10. 12.
#   3.  7. 12. 11. 10. 12.  3.  6.  8.  7.  8.  5.  5.  5.  7. 13. 17. 13.
#   9.  9. 10.  7.  9.  1.  1.  3.  4.  7.  8.  8.  8. 13. 11.  9.  8.  7.
#   2.  2.  4. 10. 15. 14. 10.  8.  7.  5.  7.  7. 10. 12. 11. 11. 10.  8.
#   4.  9.  9. 10. 10.  5.  4.  4.  5. 13. 11.  7.  7.  6.  7.  7.  7.  5.
#   5. 11. 12. 12.  6.  4.  8.  8.  8.  6. 11. 11. 11.  4.  8. 10. 10.  3.
# ...
